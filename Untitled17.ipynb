# %% [markdown]
# <a href="https://colab.research.google.com/github/suryareddy1376/DeepLearning/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 752.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 104.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.2/225.2 kB 24.0 MB/s eta 0:00:00
# ...

# %%
#! kaggle competitions download -c stat-hack-online-data-science-hackathon
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 434, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
from zipfile import ZipFile
import os

# Define paths
zip_file_path = '/content/drive/MyDrive/StatHack.zip' # Replace with your file's path
extraction_path = '/content/train'

os.makedirs(extraction_path, exist_ok=True)

# Extract the zip file
with ZipFile(zip_file_path, 'r') as zip_obj:
    zip_obj.extractall(extraction_path)

# %%
# ! rm -rf /content/trainn

# %%
import os,shutil,pathlib,random

base_dir = pathlib.Path('/content')

# %%
# for category in (
#     "Acne",
#     "Actinic_Keratosis",
#     "Benign_tumors",
#     "Bullous",
#     "Candidiasis",
#     "DrugEruption",
#     "Eczema",
#     "Infestations_Bites",
#     "Lichen",
#     "Lupus",
#     "Moles",
#     "Psoriasis",
#     "Rosacea",
#     "Seborrh_Keratoses",
#     "SkinCancer",
#     "Sun_Sunlight_Damage",
#     "Tinea",
#     "Unknown_Normal",
#     "Vascular_Tumors",
#     "Vasculitis",
#     "Vitiligo",
#     "Warts"
# ):

source = "/content/train/train/train"
dest = "/content/trainn"

train_ratio = 0.8
val_ratio   = 0.2

random.seed(42)

for cls in os.listdir(source):
    cls_path = os.path.join(source, cls)
    if not os.path.isdir(cls_path):
        continue

    images = os.listdir(cls_path)
    random.shuffle(images)

    n = len(images)
    train_end = int(train_ratio * n)

    train_imgs = images[:train_end]
    val_imgs   = images[train_end:]

    for img in train_imgs:
        train_path = os.path.join(dest, "train", cls)
        os.makedirs(train_path, exist_ok=True)
        shutil.copy(os.path.join(cls_path, img), os.path.join(train_path, img))

    for img in val_imgs:
        val_path = os.path.join(dest, "val", cls)
        os.makedirs(val_path, exist_ok=True)
        shutil.copy(os.path.join(cls_path, img), os.path.join(val_path, img))

# %%
import tensorflow
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
train_dataset = keras.utils.image_dataset_from_directory('/content/trainn/train',image_size=(224,224),batch_size=32,label_mode="int")


validation_dataset = keras.utils.image_dataset_from_directory('/content/trainn/val',image_size=(224,224),batch_size=32,label_mode="int")
# Out:
# Found 9866 files belonging to 22 classes.
# Found 2480 files belonging to 22 classes.

# %%
restnet50_base = keras.applications.ResNet50(include_top=False,weights='imagenet',input_shape=(224,224,3))
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
def get_features_and_labels(dataset):
  all_features = []
  all_labels = []
  for images,labels in dataset:
    preprocessed_images = keras.applications.resnet50.preprocess_input(images)
    features = restnet50_base.predict(preprocessed_images)
    all_features.append(features)
    all_labels.append(labels)
  return np.concatenate(all_features),np.concatenate(all_labels)

# %%
train_features,train_labels = get_features_and_labels(train_dataset)
validation_features,validation_labels = get_features_and_labels(validation_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ...

# %%
train_features.shape
# Out:
# (9866, 7, 7, 2048)

# %%
feaures=[
    "Acne",
    "Actinic_Keratosis",
    "Benign_tumors",
    "Bullous",
    "Candidiasis",
    "DrugEruption",
    "Eczema",
    "Infestations_Bites",
    "Lichen",
    "Lupus",
    "Moles",
    "Psoriasis",
    "Rosacea",
    "Seborrh_Keratoses",
    "SkinCancer",
    "Sun_Sunlight_Damage",
    "Tinea",
    "Unknown_Normal",
    "Vascular_Tumors",
    "Vasculitis",
    "Vitiligo",
    "Warts"
]

len(feaures)
# Out:
# 22

# %%
input = keras.Input(shape=train_features.shape[1:])
h = keras.layers.Flatten()(input)
h = keras.layers.Dense(256,activation="relu")(h)
h = keras.layers.Dropout(.5)(h)
output = keras.layers.Dense(22,activation="softmax")(h)
model = keras.Model(input,output)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 7, 7, 2048)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    25,690,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 22)             │         5,654 │
# ...

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
history = model.fit(train_features,train_labels,epochs=10,validation_data=(validation_features,validation_labels))
# Out:
# Epoch 1/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 75s 242ms/step - accuracy: 0.2007 - loss: 2.6945 - val_accuracy: 0.2282 - val_loss: 2.6164
# Epoch 2/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 89s 287ms/step - accuracy: 0.2069 - loss: 2.6904 - val_accuracy: 0.2335 - val_loss: 2.6216
# Epoch 3/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 102s 330ms/step - accuracy: 0.2063 - loss: 2.6511 - val_accuracy: 0.2274 - val_loss: 2.6751
# Epoch 4/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 92s 297ms/step - accuracy: 0.2254 - loss: 2.5876 - val_accuracy: 0.2323 - val_loss: 2.5705
# Epoch 5/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 102s 330ms/step - accuracy: 0.2229 - loss: 2.5681 - val_accuracy: 0.2319 - val_loss: 2.5551
# Epoch 6/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 74s 238ms/step - accuracy: 0.2217 - loss: 2.5933 - val_accuracy: 0.2379 - val_loss: 2.5722
# Epoch 7/10
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 75s 244ms/step - accuracy: 0.2284 - loss: 2.5747 - val_accuracy: 0.2339 - val_loss: 2.5508
# Epoch 8/10
# ...

# %%
plt.figure(figsize=(10,10))
for images,_ in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.axis("off")

# %%
# Input layer
input = keras.Input(shape = (224,224,3))

# # We can insert the data augmentation layer when the dataset size is low
# x = keras.layers.RandomFlip("horizontal")(input)
# x = keras.layers.RandomZoom(.1)(x)
# x = keras.layers.RandomRotation(.1)(x)


# Convulutional Block 1

x = keras.layers.Conv2D(32,kernel_size=(2,2),activation="relu",name = "Conv_1")(input)

# MaxPool layer

x = keras.layers.MaxPool2D()(x)

# Convultional Block 2

x = keras.layers.Conv2D(32,kernel_size=(2,2),activation="relu",name = "Conv_2")(x)

# MaxPool layer

x = keras.layers.MaxPool2D()(x)

# flattening the images

x = keras.layers.Flatten()(x)

# Output layer
output = keras.layers.Dense(22,activation = "softmax")(x)

model = keras.Model(input,output)

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_1 (Conv2D)                 │ (None, 223, 223, 32)   │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_2 (Conv2D)                 │ (None, 110, 110, 32)   │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 55, 55, 32)     │             0 │
# ...

# %%
keras.utils.plot_model(model,show_shapes=True)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(train_dataset,epochs=20,validation_data=validation_dataset)
# Out:
# Epoch 1/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 45s 139ms/step - accuracy: 0.0978 - loss: 445.8973 - val_accuracy: 0.1778 - val_loss: 2.9054
# Epoch 2/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 40s 130ms/step - accuracy: 0.3432 - loss: 2.3480 - val_accuracy: 0.1891 - val_loss: 3.1580
# Epoch 3/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.4885 - loss: 1.8402 - val_accuracy: 0.2113 - val_loss: 3.9198
# Epoch 4/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 40s 130ms/step - accuracy: 0.6070 - loss: 1.4428 - val_accuracy: 0.2262 - val_loss: 4.7876
# Epoch 5/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 43s 138ms/step - accuracy: 0.6941 - loss: 1.1563 - val_accuracy: 0.2278 - val_loss: 5.5271
# Epoch 6/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 40s 131ms/step - accuracy: 0.7603 - loss: 0.9080 - val_accuracy: 0.2379 - val_loss: 6.4283
# Epoch 7/20
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.8089 - loss: 0.7549 - val_accuracy: 0.2165 - val_loss: 7.3078
# Epoch 8/20
# ...

# %%
# Let's create the Functions for plotting the Validation error and accuracy curves

def plot_val_los(history):
  plt.clf()
  history_dict = history.history
  loss = history_dict['loss']
  val_loss_values = history_dict['val_loss']
  epochs = range(1,len(val_loss_values)+1)
  plt.plot(epochs,loss,"ro",label = "Training Loss")
  plt.plot(epochs,val_loss_values,"b",label = "Validation Loss")
  plt.title("Training and Validation Loss")
  plt.xlabel("Epochs")
  plt.ylabel("Loss")
  plt.show()


def plot_acc_los(history):
  plt.clf()
  history_dict = history.history
  accuracy = history_dict['accuracy']
  val_acc = history_dict['val_accuracy']
  epochs = range(1,len(accuracy)+1)
  plt.plot(epochs,accuracy,"ro",label = "Training accuracy")
  plt.plot(epochs,val_acc,"b",label = "Validation accuracy")
  plt.title("Accuracy")
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.show()

# %%
# Plotting the Loss of Training and validation

plot_val_los(history)

# %%
#Plotting the Accuracy

plot_acc_los(history)

# %%
test_dataset = keras.utils.image_dataset_from_directory(
    base_dir / "test",
    image_size=(224,224),
    batch_size=32,
    label_mode="int",
    shuffle=False   # ⚠️ CRITICAL
)
# Out:
# Found 3096 files belonging to 1 classes.

# %%
model.evaluate(test_dataset)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 14s 143ms/step - accuracy: 0.0414 - loss: 42.5317
# [60.323001861572266, 0.02810077555477619]
